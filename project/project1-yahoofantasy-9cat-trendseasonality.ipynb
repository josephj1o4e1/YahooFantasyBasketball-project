# %% [markdown]
# # Player Performance Prediction: Time Series Analysis

# %% [markdown]
# # Intro
# In the previous section, we predict daily performance using weighted average, and used multi-profit 0/1 knapsack to build the 13 man roster.
#
# Now I want to focus on improving my prediction of daily performance using Time Series Analysis.
# We first perform simple *OLS regression* to predict daily performance.
# Then we start performing time series analysis that breaks into a few parts:
# - Trend (time dependence)
# - Seasonality (time dependence)
# - Cycles (serial dependence)
# - Hybrid

# %% [markdown]
# # 1. Data Scraping and Preprocessing

# %% [markdown]
# Let's Create the time series data for every single player.
# We will use the "player box score" data.
# We used years 2021~2024 for the weighted average prediction in the previous section.
# It's only reasonable to also use 2021~2024 for our time series data to compare the method's performance.

# %% [markdown]
# Let's first get 2021~2023 player box score and save it as pbs2021.csv ~ pbs2023.csv
# We will deal with the current 2024 season later.

# %%
# Use basketball_reference_web_scraper package.  https://jaebradley.github.io/basketball_reference_web_scraper/  
from basketball_reference_web_scraper import client
import pandas as pd
import time
import requests
import datetime
import os

# %%
season_start_end_Dates = {
    '2021': 
    {'start_date': datetime.date(2020, 12, 22), 
    'end_date': datetime.date(2021, 5, 16)}, 
    '2022':
    {'start_date': datetime.date(2021, 10, 19), 
    'end_date': datetime.date(2022, 4, 10)},
    '2023':
    {'start_date': datetime.date(2022, 10, 18), 
    'end_date': datetime.date(2023, 4, 9)},
    '2024':
    {'start_date': datetime.date(2023, 10, 24), 
    'end_date': min(datetime.date(2023, 4, 14), datetime.date.today())}
}

df_pbs = {}
for yr in range(2021, 2024): # 2021~2023
    if f'pbs{yr}.csv' in os.listdir():
        df_pbs[str(yr)] = pd.read_csv(f'pbs{yr}.csv', index_col=0, parse_dates=['date']) 
    else:
        date = season_start_end_Dates[str(yr)]['start_date']
        enddate = season_start_end_Dates[str(yr)]['end_date']
        while date <= enddate: 
            try: 
                df_tmp = pd.DataFrame.from_dict(client.player_box_scores(day=date.day, month=date.month, year=date.year))
            except requests.exceptions.HTTPError as err:
                print(f'A HTTPError was thrown: {err.code} {err.reason}')
                df_pbs[str(yr)].to_csv(f'pbs{str(yr)}.csv')

            df_tmp['date'] = date
            if str(yr) not in df_pbs:
                df_pbs[str(yr)] = df_tmp
            else: 
                df_pbs[str(yr)] = pd.concat([df_pbs[str(yr)], df_tmp])
            date = date + datetime.timedelta(1)
            time.sleep(15) # delay for 5 seconds. sometimes you'll need 20 seconds

        df_pbs[str(yr)].to_csv(f'pbs{str(yr)}.csv')

df_pbs['2021'].head()
# Out:
#         slug              name                       team       location  \
# 0  georgpa01       Paul George  Team.LOS_ANGELES_CLIPPERS  Location.AWAY
# 1  irvinky01      Kyrie Irving         Team.BROOKLYN_NETS  Location.HOME
# 2  harremo01  Montrezl Harrell    Team.LOS_ANGELES_LAKERS  Location.HOME
# 3  duranke01      Kevin Durant         Team.BROOKLYN_NETS  Location.HOME
# 4  leverca01      Caris LeVert         Team.BROOKLYN_NETS  Location.HOME
#
#                      opponent       outcome  seconds_played  made_field_goals  \
# 0     Team.LOS_ANGELES_LAKERS   Outcome.WIN          2146.0              13.0
# 1  Team.GOLDEN_STATE_WARRIORS   Outcome.WIN          1518.0              10.0
# 2   Team.LOS_ANGELES_CLIPPERS  Outcome.LOSS          1935.0               6.0
# 3  Team.GOLDEN_STATE_WARRIORS   Outcome.WIN          1496.0               7.0
# 4  Team.GOLDEN_STATE_WARRIORS   Outcome.WIN          1489.0               6.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   18.0                           5.0  ...
# 1                   16.0                           4.0  ...
# 2                    7.0                           0.0  ...
# 3                   16.0                           1.0  ...
# 4                   17.0                           3.0  ...
#
#    attempted_free_throws  offensive_rebounds  defensive_rebounds  assists  \
# 0                    2.0                 0.0                 6.0      3.0
# 1                    2.0                 1.0                 3.0      4.0
# 2                    7.0                 4.0                 6.0      3.0
# 3                    7.0                 1.0                 4.0      3.0
# 4                    6.0                 1.0                 8.0      5.0
#
#    steals  blocks  turnovers  personal_fouls  game_score       date
# 0     1.0     0.0        5.0             3.0        24.3 2020-12-22
# 1     0.0     0.0        1.0             3.0        21.0 2020-12-22
# 2     0.0     1.0        1.0             1.0        19.7 2020-12-22
# 3     3.0     1.0        1.0             3.0        19.1 2020-12-22
# 4     2.0     1.0        2.0             1.0        17.0 2020-12-22
#
# [5 rows x 22 columns]

# %% [markdown]
# Now let's get the current up-to-date player box score for this season (2023-2024)

# %%
date = season_start_end_Dates['2024']['start_date']
enddate = season_start_end_Dates['2024']['end_date']
if 'pbs2024.csv' in os.listdir():
    df_pbs['2024'] = pd.read_csv(f'pbs2024.csv', index_col=0, parse_dates=['date'])
    date = df_pbs['2024']['date'].max().date()

while date <= enddate: 
    try: 
        df_tmp = pd.DataFrame.from_dict(client.player_box_scores(day=date.day, month=date.month, year=date.year))
    except requests.exceptions.HTTPError as err:
        print(f'A HTTPError was thrown: {err}')
        df_pbs['2024'].to_csv(f'pbs2024.csv')

    df_tmp['date'] = date
    if '2024' not in df_pbs:
        df_pbs['2024'] = df_tmp
    else: 
        df_pbs['2024'] = pd.concat([df_pbs['2024'], df_tmp])
    date = date + datetime.timedelta(1)
    print(f'{date} finished')
    time.sleep(10) # delay for 5 seconds. sometimes you'll need 20 seconds

df_pbs['2024'].to_csv(f'pbs2024.csv')

# %% [markdown]
# Preprocess some of the data into a more 9-cat friendly features.

# %%
for yr in range(2021, 2025):
    df_pbs[str(yr)]['pts'] = df_pbs[str(yr)]['made_free_throws'] + df_pbs[str(yr)]['made_three_point_field_goals']*3 + (df_pbs[str(yr)]['made_field_goals']-df_pbs[str(yr)]['made_three_point_field_goals'])*2
    df_pbs[str(yr)]['FGperc'] = df_pbs[str(yr)]['made_field_goals'] / df_pbs[str(yr)]['attempted_field_goals']
    df_pbs[str(yr)]['FTperc'] = df_pbs[str(yr)]['made_free_throws'] / df_pbs[str(yr)]['attempted_free_throws']
    df_pbs[str(yr)]['rebs'] = df_pbs[str(yr)]['offensive_rebounds'] + df_pbs[str(yr)]['defensive_rebounds']

df_pbs['2024'].head()
# Out:
#         slug          name                     team       location  \
# 0  jokicni01  Nikola Jokić      Team.DENVER_NUGGETS  Location.HOME
# 1  bookede01  Devin Booker        Team.PHOENIX_SUNS  Location.AWAY
# 2  jamesle01  LeBron James  Team.LOS_ANGELES_LAKERS  Location.AWAY
# 3  gordoaa01  Aaron Gordon      Team.DENVER_NUGGETS  Location.HOME
# 4  murraja01  Jamal Murray      Team.DENVER_NUGGETS  Location.HOME
#
#                      opponent       outcome  seconds_played  made_field_goals  \
# 0     Team.LOS_ANGELES_LAKERS   Outcome.WIN          2176.0              12.0
# 1  Team.GOLDEN_STATE_WARRIORS   Outcome.WIN          2218.0              13.0
# 2         Team.DENVER_NUGGETS  Outcome.LOSS          1740.0              10.0
# 3     Team.LOS_ANGELES_LAKERS   Outcome.WIN          2099.0               7.0
# 4     Team.LOS_ANGELES_LAKERS   Outcome.WIN          2055.0               8.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  steals  blocks  \
# 0                   22.0                           3.0  ...     1.0     1.0
# 1                   21.0                           3.0  ...     1.0     0.0
# 2                   16.0                           1.0  ...     1.0     0.0
# 3                   11.0                           1.0  ...     2.0     1.0
# 4                   13.0                           3.0  ...     0.0     1.0
#
#    turnovers  personal_fouls  game_score       date   pts    FGperc  FTperc  \
# 0        2.0             2.0        29.3 2023-10-24  29.0  0.545455     0.5
# 1        6.0             4.0        23.7 2023-10-24  32.0  0.619048     1.0
# 2        0.0             1.0        20.3 2023-10-24  21.0  0.625000     0.0
# 3        0.0             0.0        19.2 2023-10-24  15.0  0.636364     NaN
# 4        1.0             3.0        18.4 2023-10-24  21.0  0.615385     1.0
#
#    rebs
# 0  13.0
# 1   6.0
# 2   8.0
# 3   7.0
# 4   2.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # 2. Time Series Analysis

# %% [markdown]
# 0. OLS regression
# 1. Trend (time dependence)
# 2. Seasonality (time dependence)
# 3. Cycles (serial dependence)
# 4. Hybrid
#
# We will first try single player performance prediction.
# "Tyrese Haliburton" for example.

# %% [markdown]
# **0. OLS Regression**
# We will use "lag features" to model our OLS regression.
# This lag features let us model "serial dependence" rather than time dependence.

# %% [markdown]
# Get player Tyrese Haliburton's data from 2021~2024.

# %%
name0='Tyrese Haliburton'
# name0='Precious Achiuwa'
df_name0 = None
for yr in range(2021, 2025):
    if df_name0 is None:
        df_name0 = df_pbs[str(yr)][df_pbs[str(yr)]['name']==name0]
    else:
        df_name0 = pd.concat([df_name0, df_pbs[str(yr)][df_pbs[str(yr)]['name']==name0]])
df_name0.sort_values(by='date', ascending=True)
df_name0.head()
# Out:
#           slug               name                   team       location  \
# 58   halibty01  Tyrese Haliburton  Team.SACRAMENTO_KINGS  Location.AWAY
# 156  halibty01  Tyrese Haliburton  Team.SACRAMENTO_KINGS  Location.HOME
# 30   halibty01  Tyrese Haliburton  Team.SACRAMENTO_KINGS  Location.HOME
# 30   halibty01  Tyrese Haliburton  Team.SACRAMENTO_KINGS  Location.HOME
# 66   halibty01  Tyrese Haliburton  Team.SACRAMENTO_KINGS  Location.AWAY
#
#                  opponent       outcome  seconds_played  made_field_goals  \
# 58    Team.DENVER_NUGGETS   Outcome.WIN          1800.0               3.0
# 156     Team.PHOENIX_SUNS   Outcome.WIN          1569.0               1.0
# 30      Team.PHOENIX_SUNS  Outcome.LOSS          1592.0               5.0
# 30    Team.DENVER_NUGGETS   Outcome.WIN          1494.0               5.0
# 66   Team.HOUSTON_ROCKETS  Outcome.LOSS          1603.0               4.0
#
#      attempted_field_goals  made_three_point_field_goals  ...  steals  blocks  \
# 58                     7.0                           2.0  ...     0.0     1.0
# 156                    4.0                           0.0  ...     0.0     1.0
# 30                     7.0                           3.0  ...     0.0     0.0
# 30                     7.0                           3.0  ...     3.0     0.0
# 66                     9.0                           2.0  ...     2.0     0.0
#
#      turnovers  personal_fouls  game_score       date   pts    FGperc  FTperc  \
# 58         0.0             0.0        12.8 2020-12-23  12.0  0.428571     1.0
# 156        1.0             2.0         2.6 2020-12-26   2.0  0.250000     NaN
# 30         0.0             2.0        16.2 2020-12-27  15.0  0.714286     1.0
# 30         2.0             1.0        16.2 2020-12-29  13.0  0.714286     NaN
# 66         1.0             2.0         7.4 2020-12-31  11.0  0.444444     0.5
#
#      rebs
# 58    2.0
# 156   2.0
# 30    1.0
# 30    3.0
# 66    2.0
#
# [5 rows x 26 columns]

# %% [markdown]
# Add Time Dummy

# %%
import numpy as np
df_name0['time'] = np.arange(len(df_name0.index))

# %% [markdown]
# Set the independent variable X = value of previous day,
# and the dependent variable y = value of current day.

# %%
from sklearn.linear_model import LinearRegression

# %%
df_tmp = df_name0.copy()
df_tmp['pts_lag1'] = df_tmp['pts'].shift(1)

# drop rows with pts_lag1==NaN
df_tmp = df_tmp[~df_tmp['pts_lag1'].isna()][['pts', 'pts_lag1']]
X = df_tmp[['pts_lag1']]
y = df_tmp[['pts']]

df_tmp
# Out:
#       pts  pts_lag1
# 156   2.0      12.0
# 30   15.0       2.0
# 30   13.0      15.0
# 66   11.0      13.0
# 17   17.0      11.0
# ..    ...       ...
# 0    31.0      31.0
# 13   10.0      31.0
# 13   17.0      10.0
# 13   17.0      17.0
# 74    7.0      17.0
#
# [245 rows x 2 columns]

# %% [markdown]
# Split the data into Training set and Testing set.

# %%
train_size = int(len(df_tmp) * 0.8)
train_X, test_X = X[:train_size], X[train_size:]
train_y, test_y = y[:train_size], y[train_size:]

# %% [markdown]
# Train

# %%
model = LinearRegression()
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %% [markdown]
# Test

# %%
test_idx = test_X.index
y_pred = pd.Series(model.predict(test_X).flatten(), index=test_idx)
y_pred
# Out:
# 24     18.240065
# 2      16.350375
# 2      19.859799
# 0      18.779976
# 161    20.939622
# 0      15.270552
# 4      22.019445
# 16     20.939622
# 3      19.049932
# 1      20.939622
# 1      23.909135
# 0      19.049932
# 17     19.319888
# 8      17.430198
# 21     17.700153
# 22     17.160242
# 0      16.890286
# 27     23.639179
# 24     18.240065
# 2      16.350375
# 2      19.859799
# 0      18.779976
# 161    20.939622
# 0      15.270552
# 4      22.019445
# 16     20.939622
# 3      19.049932
# 1      20.939622
# 1      23.909135
# 0      19.049932
# 2      19.319888
# 60     17.430198
# 35     15.810464
# 44     17.970109
# 146    17.160242
# 22     14.190729
# 54     17.160242
# 6      16.620331
# 5      19.859799
# 3      20.939622
# 2      17.700153
# 4      17.970109
# 0      19.049932
# 0      20.399710
# 0      20.399710
# 13     20.399710
# 13     14.730641
# 13     16.620331
# 74     16.620331
# dtype: float64

# %% [markdown]
# Plot whole data trend with the predicted data ontop in a different color.

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
category = 'pts'

train_idx = df_name0.iloc[:train_size].index
ytrain_pred = pd.Series(model.predict(train_X).flatten(), index=train_idx)

fig, ax = plt.subplots()
ax.plot('time', category, data=df_name0, color='0.75')
ax.plot(df_name0.iloc[:train_size]['time'], ytrain_pred, color='blue', label="training data predict")
ax.plot(df_name0.iloc[train_size+1:]['time'], y_pred, color='red', label="test data prediction")
ax.legend()
ax.set_title(f'Time Plot of {name0} in \'points\' ')
# Out:
# C:\Users\joe_c\AppData\Local\Temp\ipykernel_27564\1353265969.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
# Text(0.5, 1.0, "Time Plot of Tyrese Haliburton in 'points' ")

# %% [markdown]
# Although the shape seems somehow reasonable, the model is mostly underestimating high points of Haliburton and overestimating the low points of Haliburton.
# It has a "conservative" guess of the points of Tyrese Haliburton.
# Can we improve?
#
# Next, utilize even more common time series analysis techniques regarding "time dependence": Trend, Seasonality.
# First we deal with "trend".

# %% [markdown]
# **1. Trend**

# %%
from statsmodels.tsa.deterministic import DeterministicProcess

dp = DeterministicProcess(
    index=df_name0.index,  # dates from the training data
    constant=True,       # dummy feature for the bias (y_intercept)
    order=1,             # the time dummy (trend)
    drop=True,           # drop terms if necessary to avoid collinearity
)
# `in_sample` creates features for the dates given in the `index` argument
X = dp.in_sample()

X.head()
# Out:
#      const  trend
# 58     1.0    1.0
# 156    1.0    2.0
# 30     1.0    3.0
# 30     1.0    4.0
# 66     1.0    5.0

# %%
from sklearn.linear_model import LinearRegression

y = df_name0[category]  # the target

# The intercept is the same as the `const` feature from
# DeterministicProcess. LinearRegression behaves badly with duplicated
# features, so we need to be sure to exclude it here.
model = LinearRegression(fit_intercept=False)
model.fit(X, y)

y_pred = pd.Series(model.predict(X).flatten(), index=X.index)
ax.plot(df_name0['time'], y_pred, color='green', label="Trend (OLS)")
ax.legend()
display(fig)

# %% [markdown]
# The overall trend of Tyrese Haliburton's points is increasing.
#
# Another way of analyzing the trend is using moving average by using the pandas rolling window function.

# %%
trend = df_name0[category].rolling(window=100, center=True, min_periods=50).mean()
ax.plot(df_name0['time'], trend, color='yellow', label="Trend (window func)")
ax.legend()
display(fig)

# %% [markdown]
# **2. Seasonality**
# Perform "Harmonic Regression": detect and model *seasonality* using Fourier Features and fast fourier transform.

# %% [markdown]
# - Generate the periodogram of the time series (using fast fourier transform).
# - Create fourier features according to the strong frequencies in the periodogram.
# - Add the fourier features to our dependent variables using DeterministicProcess.
# - Use Linear Regression (OLS) to model the seasonality.

# %%
from scipy.signal import periodogram

ts = y
fs = 1 # len(ts) # sampling_freq

# Remember to detrend and apply windowing for better fft result. 
# The periodogram function uses Welch's method. 
f, psd = periodogram(
                        ts,
                        fs=fs, # (twosided) freqs = sp_fft.fftfreq(nfft, 1/fs)
                        detrend="linear",
                        window="boxcar",
                        scaling='spectrum', # scale = 1.0 / win.sum()**2
                    )

indexes = list(range(len(f)))
indexes.sort(key = lambda i: np.absolute(psd[i]))
indexes.reverse()
print(f"Top 3 frequencies (in a game period): ")
top3_freq = []
# for i in indexes[:3]:
i=0
while len(top3_freq)<3:
    if 1/f[indexes[i]]<100:
        top3_freq.append(1/f[indexes[i]])
        print(f"{1/f[indexes[i]]}, i={indexes[i]}")
    i+=1

_, ax = plt.subplots()
ax.step(f[f>=0], psd[f>=0], color="purple")
ax.set_title(f'Periodogram of {name0}\'s {category}')
ax
# Out:
# Top 3 frequencies (in a game period):
# 8.482758620689655, i=29
# 16.4, i=15
# 2.5625, i=96
# <Axes: title={'center': "Periodogram of Tyrese Haliburton's pts"}>

# %% [markdown]
# Choose these 3 frequencies for our 3 fourier feature pairs.

# %%
from statsmodels.tsa.deterministic import DeterministicProcess, Fourier

# %%
index = [i for i in range(len(y))]

# "order" amount of sin/cos Fourier pairs with a certain period.  
# 2 * order must be <= period 
# (period is the 1/freq of the trigonometric function)
fourier1 = Fourier(period=top3_freq[0], order=int(top3_freq[0]/2))  
print(f'fourier1: period={top3_freq[0]}, order={int(top3_freq[0]/2)}')
fourier2 = Fourier(period=top3_freq[1], order=int(top3_freq[1]/2))
print(f'fourier2: period={top3_freq[1]}, order={int(top3_freq[1]/2)}')
fourier3 = Fourier(period=top3_freq[2], order=int(top3_freq[2]/2))
print(f'fourier3: period={top3_freq[2]}, order={int(top3_freq[2]/2)}')
fourier = [fourier1, fourier2, fourier3]

# print(fourier.in_sample(index))

dp = DeterministicProcess(
    index=index, 
    constant=True, 
    order=1, 
    drop=True, 
    seasonal=False, 
    additional_terms=[*fourier]
)

Xsea = dp.in_sample()
print(Xsea.head())
# Out:
# fourier1: period=8.482758620689655, order=4
# fourier2: period=16.4, order=8
# fourier3: period=2.5625, order=1
#    const  trend  sin(1,8.48)  cos(1,8.48)  sin(2,8.48)  cos(2,8.48)  \
# 0    1.0    1.0     0.000000     1.000000     0.000000     1.000000
# 1    1.0    2.0     0.674805     0.737996     0.996007     0.089276
# 2    1.0    3.0     0.996007     0.089276     0.177839    -0.984060
# 3    1.0    4.0     0.795293    -0.606225    -0.964253    -0.264982
# 4    1.0    5.0     0.177839    -0.984060    -0.350008     0.936747
#
#    sin(3,8.48)  cos(3,8.48)  sin(4,8.48)  cos(4,8.48)  ...  sin(5,16.40)  \
# 0     0.000000     1.000000     0.000000     1.000000  ...      0.000000
# 1     0.795293    -0.606225     0.177839    -0.984060  ...      0.941140
# 2    -0.964253    -0.264982    -0.350008     0.936747  ...     -0.636242
# 3     0.373817     0.927502     0.511019    -0.859570  ...     -0.511019
# 4     0.511019    -0.859570    -0.655738     0.754989  ...      0.981708
#
#    cos(5,16.40)  sin(6,16.40)  cos(6,16.40)  sin(7,16.40)  cos(7,16.40)  \
# 0      1.000000      0.000000      1.000000      0.000000      1.000000
# 1     -0.338017      0.746553     -0.665326      0.443720     -0.896166
# 2     -0.771489     -0.993402     -0.114683     -0.795293      0.606225
# 3      0.859570      0.575319      0.817929      0.981708     -0.190391
# 4      0.190391      0.227854     -0.973695     -0.964253     -0.264982
#
#    sin(8,16.40)  cos(8,16.40)  sin(1,2.56)  cos(1,2.56)
# 0      0.000000      1.000000     0.000000     1.000000
# 1      0.076549     -0.997066     0.636242    -0.771489
# 2     -0.152649      0.988280    -0.981708     0.190391
# 3      0.227854     -0.973695     0.878512     0.477720
# 4     -0.301721      0.953396    -0.373817    -0.927502
#
# [5 rows x 28 columns]

# %% [markdown]
# Finally, let's use Linear Regression (OLS) to model the seasonality from the above.

# %%
train_size = int(len(df_tmp) * 0.8)
train_Xsea, test_Xsea = Xsea[:train_size], Xsea[train_size:]
train_y, test_y = y[:train_size], y[train_size:]
model = LinearRegression(fit_intercept=False)
model.fit(train_Xsea, train_y)
# Out:
# LinearRegression(fit_intercept=False)

# %% [markdown]
# Test

# %%
test_idx = test_Xsea.index
ySea_pred = pd.Series(model.predict(test_Xsea).flatten(), index=test_idx)

ySea_pred
# Out:
# 196    20.968703
# 197    27.050183
# 198    23.303197
# 199    20.667748
# 200    27.661895
# 201    23.145076
# 202    24.028675
# 203    27.752589
# 204    19.544760
# 205    21.981104
# 206    24.066233
# 207    22.002522
# 208    24.823883
# 209    18.276192
# 210    23.290131
# 211    19.999123
# 212    21.402362
# 213    26.261257
# 214    24.870566
# 215    23.394414
# 216    26.224535
# 217    25.775154
# 218    27.439719
# 219    24.275414
# 220    26.219552
# 221    19.578957
# 222    22.751083
# 223    26.741612
# 224    23.262550
# 225    22.327105
# 226    24.701628
# 227    20.131883
# 228    22.869578
# 229    24.307621
# 230    25.070867
# 231    27.166990
# 232    23.395330
# 233    29.550374
# 234    28.158820
# 235    25.937546
# 236    28.625540
# 237    20.613914
# 238    21.822403
# 239    26.796281
# 240    24.561362
# 241    26.214461
# 242    22.570569
# 243    25.920479
# 244    22.236410
# 245    22.505189
# dtype: float64

# %% [markdown]
# Plot

# %%
plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
category = 'pts'


train_idx = train_Xsea.index
ySeatrain_pred = pd.Series(model.predict(train_Xsea).flatten(), index=train_idx)

fig, ax = plt.subplots()
ax.plot('time', category, data=df_name0, color='0.75')
ax.plot(df_name0.iloc[:train_size]['time'], ySeatrain_pred, color='blue', label="training data predict")
ax.plot(df_name0.iloc[train_size:]['time'], ySea_pred, color='red', label="testing data predict")
ax.set_title(f'Time Plot of {name0} in \'points\' ')
ax.legend()
# Out:
# C:\Users\joe_c\AppData\Local\Temp\ipykernel_27564\1710511669.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %% [markdown]
# The overall prediction seems better than the OLS regression model that only uses 1 lag feature.
# The points were less conservative than before.  And the prediction curve is much closer to the target curve.
# However, in the prediction there seems to be having some incorrect prediction between games 200~220
# Would having some serial dependence analysis on Cycles help?
